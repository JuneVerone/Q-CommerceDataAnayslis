# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('quick_commerce_data_raw.csv')

df.head()
print(df)
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# ...

# %%
#data structure
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Order_ID                 1000000 non-null  int64
#  1   Company                  1000000 non-null  str
#  2   City                     948000 non-null   str
#  3   Customer_Age             1000000 non-null  int64
#  4   Order_Value              1000000 non-null  float64
#  5   Delivery_Time_Min        1000000 non-null  float64
#  6   Distance_Km              1000000 non-null  float64
#  7   Items_Count              965000 non-null   float64
#  8   Product_Category         1000000 non-null  str
#  9   Payment_Method           1000000 non-null  str
#  10  Customer_Rating          953000 non-null   float64
#  11  Discount_Applied         1000000 non-null  int64
#  12  Delivery_Partner_Rating  895863 non-null   float64
# dtypes: float64(6), int64(3), str(4)
# ...

# %%
#data summary statistics
df.describe()
# Out:
#            Order_ID    Customer_Age     Order_Value  Delivery_Time_Min  \
# count  1.000000e+06  1000000.000000  1000000.000000     1000000.000000
# mean   1.500000e+06       38.470387      571.643584          16.452412
# std    2.886753e+05       12.118520      382.784520           6.257172
# min    1.000001e+06       18.000000       50.000000           5.000000
# 25%    1.250001e+06       28.000000      287.840150          12.368000
# 50%    1.500000e+06       38.000000      531.324600          16.342000
# 75%    1.750000e+06       49.000000      796.182500          20.196000
# max    2.000000e+06       59.000000    13877.325000          40.000000
#
#           Distance_Km    Items_Count  Customer_Rating  Discount_Applied  \
# count  1000000.000000  965000.000000    953000.000000    1000000.000000
# mean         7.750231       9.998317         3.042072          0.400883
# std          4.186665       5.478725         1.186872          0.490078
# ...

# %%
# checking for missing values isnull().sum() or isna().sum() 
# can be used to check for missing values in the dataset. 
# The output will show the number of missing values in each column of the dataframe.
df.isnull().sum()
# Out:
# Order_ID                        0
# Company                         0
# City                        52000
# Customer_Age                    0
# Order_Value                     0
# Delivery_Time_Min               0
# Distance_Km                     0
# Items_Count                 35000
# Product_Category                0
# Payment_Method                  0
# Customer_Rating             47000
# Discount_Applied                0
# Delivery_Partner_Rating    104137
# dtype: int64

# %%
# shows the rows with missing values in the dataframe. 
# The output will be a new dataframe that contains only the rows with missing values.
df[df.isnull().any(axis=1)]
# Out:
#         Order_ID           Company       City  Customer_Age  Order_Value  \
# 2        1000003  Flipkart Minutes     Mumbai            18   1211.66000
# 6        1000007           Blinkit   Bengluru            37    516.86480
# 17       1000018             Zepto      Delhi            23   1041.42975
# 21       1000022           Blinkit        NaN            41    716.89860
# 22       1000023          Jio Mart      Delhi            48     50.00000
# ...          ...               ...        ...           ...          ...
# 999966   1999967             Dunzo        NaN            39    783.89250
# 999975   1999976        Amazon Now   Bengluru            34    515.89380
# 999981   1999982        Amazon Now        NaN            33    939.34470
# 999983   1999984  Swiggy Instamart  Hyderabad            42     50.00000
# 999990   1999991        Amazon Now      Delhi            39    781.65420
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# ...

# %%
#shows the rows with all missing values in the dataframe.
df[df.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Company, City, Customer_Age, Order_Value, Delivery_Time_Min, Distance_Km, Items_Count, Product_Category, Payment_Method, Customer_Rating, Discount_Applied, Delivery_Partner_Rating]
# Index: []

# %%
df2 = df.dropna(subset=['City']).copy()
print("Number of rows after dropping rows with missing values in 'City' column:", len(df2))
df2.head()
# Out:
# Number of rows after dropping rows with missing values in 'City' column: 948000
#    Order_ID           Company      City  Customer_Age  Order_Value  \
# 0   1000001  Swiggy Instamart     Noida            46    702.33750
# 1   1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2   1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3   1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4   1000005             Dunzo    Mumbai            44    586.02550
#
#    Delivery_Time_Min  Distance_Km  Items_Count Product_Category  \
# 0             19.182        11.97         12.0            Dairy
# 1             19.644        12.74         10.0           Snacks
# 2             16.910         4.85          NaN    Personal Care
# 3              5.864         6.44          2.0            Dairy
# 4             12.470         2.45         13.0        Household
#
#      Payment_Method  Customer_Rating  Discount_Applied  \
# ...

# %%
x = df2['Items_Count'].mode()[0] # Find the mode (scalar) of 'Items_Count'
df['Items_Count'] = df['Items_Count'].fillna(x) # Fill missing values with the mode

print("Number of rows after filling missing values in 'Items_Count' column:", len(df2))
print("Items_Count mode:", x)
# Out:
# Number of rows after filling missing values in 'Items_Count' column: 948000
# Items_Count mode: 19.0

# %%
df['Items_Count'].fillna(x, inplace=True) # Fill missing values with the mode but using inplace=True to modify the original dataframe directly
# Out:
# C:\Users\JUNE VERON\AppData\Local\Temp\ipykernel_10620\3761109664.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Items_Count'].fillna(x, inplace=True) # Fill missing values with the mode but using inplace=True to modify the original dataframe directly
# 0         12.0
# 1         10.0
# 2         19.0
# ...

# %%
df2.isna().sum()
# Out:
# Order_ID                       0
# Company                        0
# City                           0
# Customer_Age                   0
# Order_Value                    0
# Delivery_Time_Min              0
# Distance_Km                    0
# Items_Count                33228
# Product_Category               0
# Payment_Method                 0
# Customer_Rating            44575
# Discount_Applied               0
# Delivery_Partner_Rating    98694
# dtype: int64

# %%
x = df2['Items_Count'].mode()[0] # Find the mode (scalar) of 'Items_Count'
df2['Items_Count'] = df2['Items_Count'].fillna(x) # Fill missing values with the mode
df2['Items_Count']
# Out:
# 0         12.0
# 1         10.0
# 2         19.0
# 3          2.0
# 4         13.0
#           ...
# 999995    19.0
# 999996     9.0
# 999997     6.0
# 999998    12.0
# 999999    13.0
# Name: Items_Count, Length: 948000, dtype: float64

# %%
df2['Items_Count'].isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Name: Items_Count, Length: 948000, dtype: bool

# %%
print(df2)
# Out:
#         Order_ID           Company      City  Customer_Age  Order_Value  \
# 0        1000001  Swiggy Instamart     Noida            46    702.33750
# 1        1000002  Flipkart Minutes  Amritsar            56   1007.30000
# 2        1000003  Flipkart Minutes    Mumbai            18   1211.66000
# 3        1000004  Swiggy Instamart     Delhi            23   1179.05925
# 4        1000005             Dunzo    Mumbai            44    586.02550
# ...          ...               ...       ...           ...          ...
# 999995   1999996        Big Basket    Mumbai            48     72.33000
# 999996   1999997  Swiggy Instamart    Mumbai            33   1509.66300
# 999997   1999998          Jio Mart     Noida            29    637.32300
# 999998   1999999             Dunzo      Pune            42   1103.12100
# 999999   2000000        Amazon Now   Chennai            19    758.58860
#
#         Delivery_Time_Min  Distance_Km  Items_Count     Product_Category  \
# ...

# %%
df2.isna().sum()
# Out:
# Order_ID                       0
# Company                        0
# City                           0
# Customer_Age                   0
# Order_Value                    0
# Delivery_Time_Min              0
# Distance_Km                    0
# Items_Count                    0
# Product_Category               0
# Payment_Method                 0
# Customer_Rating            44575
# Discount_Applied               0
# Delivery_Partner_Rating    98694
# dtype: int64

# %%
df.isna().sum()
# Out:
# Order_ID                        0
# Company                         0
# City                        52000
# Customer_Age                    0
# Order_Value                     0
# Delivery_Time_Min               0
# Distance_Km                     0
# Items_Count                     0
# Product_Category                0
# Payment_Method                  0
# Customer_Rating             47000
# Discount_Applied                0
# Delivery_Partner_Rating    104137
# dtype: int64

# %%
df.fillna?
# Out:
# Signature:
# df.fillna(
#     value: 'Hashable | Mapping | Series | DataFrame',
#     *,
#     axis: 'Axis | None' = None,
#     inplace: 'bool' = False,
#     limit: 'int | None' = None,
# ) -> 'Self'
# Docstring:
# Fill NA/NaN values with `value`.
#
# Parameters
# ----------
# value : scalar, dict, Series, or DataFrame
#     Value to use to fill holes (e.g. 0), alternately a
#     dict/Series/DataFrame of values specifying which value to use for
#     each index (for a Series) or column (for a DataFrame).  Values not
#     in the dict/Series/DataFrame will not be filled. This value cannot
#     be a list.
# axis : {0 or 'index'} for Series, {0 or 'index', 1 or 'columns'} for DataFrame
#     Axis along which to fill missing values. For `Series`
#     this parameter is unused and defaults to 0.
# inplace : bool, default False
#     If True, fill in-place. Note: this will modify any
#     other views on this object (e.g., a no-copy slice for a column in a
#     DataFrame).
# ...

# %%
df['City'].fillna('Unknown') # Fill missing values in 'City' column with 'Unknown'
# Out:
# 0            Noida
# 1         Amritsar
# 2           Mumbai
# 3            Delhi
# 4           Mumbai
#             ...
# 999995      Mumbai
# 999996      Mumbai
# 999997       Noida
# 999998        Pune
# 999999     Chennai
# Name: City, Length: 1000000, dtype: str

# %%
df['City'] = df['City'].fillna('Unknown')
df[df['City'] == 'Unknown'].head(10)
# Out:
#      Order_ID           Company     City  Customer_Age  Order_Value  \
# 21    1000022           Blinkit  Unknown            41     716.8986
# 43    1000044             Zepto  Unknown            51     543.4485
# 54    1000055  Flipkart Minutes  Unknown            55    1023.0300
# 59    1000060        Amazon Now  Unknown            53     275.5368
# 61    1000062        Amazon Now  Unknown            45     364.5600
# 124   1000125           Blinkit  Unknown            22     974.8296
# 143   1000144        Amazon Now  Unknown            19     807.1623
# 146   1000147             Dunzo  Unknown            21     884.2980
# 167   1000168        Big Basket  Unknown            48     399.5901
# 208   1000209             Zepto  Unknown            35     714.5985
#
#      Delivery_Time_Min  Distance_Km  Items_Count Product_Category  \
# 21              17.804        11.34          7.0        Beverages
# 43               5.000         2.32          8.0           Snacks
# ...

# %%
df.isna().sum()
# Out:
# Order_ID                        0
# Company                         0
# City                            0
# Customer_Age                    0
# Order_Value                     0
# Delivery_Time_Min               0
# Distance_Km                     0
# Items_Count                     0
# Product_Category                0
# Payment_Method                  0
# Customer_Rating             47000
# Discount_Applied                0
# Delivery_Partner_Rating    104137
# dtype: int64

# %%
df.describe()
# Out:
#            Order_ID    Customer_Age     Order_Value  Delivery_Time_Min  \
# count  1.000000e+06  1000000.000000  1000000.000000     1000000.000000
# mean   1.500000e+06       38.470387      571.643584          16.452412
# std    2.886753e+05       12.118520      382.784520           6.257172
# min    1.000001e+06       18.000000       50.000000           5.000000
# 25%    1.250001e+06       28.000000      287.840150          12.368000
# 50%    1.500000e+06       38.000000      531.324600          16.342000
# 75%    1.750000e+06       49.000000      796.182500          20.196000
# max    2.000000e+06       59.000000    13877.325000          40.000000
#
#           Distance_Km     Items_Count  Customer_Rating  Discount_Applied  \
# count  1000000.000000  1000000.000000    953000.000000    1000000.000000
# mean         7.750231       10.313376         3.042072          0.400883
# std          4.186665        5.630511         1.186872          0.490078
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Order_ID                 1000000 non-null  int64
#  1   Company                  1000000 non-null  str
#  2   City                     1000000 non-null  str
#  3   Customer_Age             1000000 non-null  int64
#  4   Order_Value              1000000 non-null  float64
#  5   Delivery_Time_Min        1000000 non-null  float64
#  6   Distance_Km              1000000 non-null  float64
#  7   Items_Count              1000000 non-null  float64
#  8   Product_Category         1000000 non-null  str
#  9   Payment_Method           1000000 non-null  str
#  10  Customer_Rating          953000 non-null   float64
#  11  Discount_Applied         1000000 non-null  int64
#  12  Delivery_Partner_Rating  895863 non-null   float64
# dtypes: float64(6), int64(3), str(4)
# ...

# %%
df[df['Delivery_Partner_Rating'].notnull()].head(25)
# Out:
#     Order_ID           Company       City  Customer_Age  Order_Value  \
# 0    1000001  Swiggy Instamart      Noida            46    702.33750
# 1    1000002  Flipkart Minutes   Amritsar            56   1007.30000
# 2    1000003  Flipkart Minutes     Mumbai            18   1211.66000
# 3    1000004  Swiggy Instamart      Delhi            23   1179.05925
# 4    1000005             Dunzo     Mumbai            44    586.02550
# 5    1000006          Jio Mart    Kolkata            57    263.08350
# 7    1000008             Dunzo    Chennai            49    291.74500
# 8    1000009  Flipkart Minutes   Bengluru            26    763.02000
# 9    1000010  Swiggy Instamart    Chennai            45    912.84700
# 10   1000011           Blinkit  Hyderabad            25    446.81760
# 11   1000012  Swiggy Instamart       Pune            47   1143.21500
# 12   1000013        Amazon Now   Haridwar            18     97.65800
# 13   1000014           Blinkit      Noida            48   1599.55860
# ...

# %%
xmean = df['Delivery_Partner_Rating'].mean() # Find the mean of 'Delivery_Partner_Rating'
df['Delivery_Partner_Rating'] = df['Delivery_Partner_Rating'].fillna(xmean) # Fill missing values with the mean

# %%
df['Delivery_Partner_Rating'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Order_ID                       0
# Company                        0
# City                           0
# Customer_Age                   0
# Order_Value                    0
# Delivery_Time_Min              0
# Distance_Km                    0
# Items_Count                    0
# Product_Category               0
# Payment_Method                 0
# Customer_Rating            47000
# Discount_Applied               0
# Delivery_Partner_Rating        0
# dtype: int64

# %%
df.describe()
# Out:
#            Order_ID    Customer_Age     Order_Value  Delivery_Time_Min  \
# count  1.000000e+06  1000000.000000  1000000.000000     1000000.000000
# mean   1.500000e+06       38.470387      571.643584          16.452412
# std    2.886753e+05       12.118520      382.784520           6.257172
# min    1.000001e+06       18.000000       50.000000           5.000000
# 25%    1.250001e+06       28.000000      287.840150          12.368000
# 50%    1.500000e+06       38.000000      531.324600          16.342000
# 75%    1.750000e+06       49.000000      796.182500          20.196000
# max    2.000000e+06       59.000000    13877.325000          40.000000
#
#           Distance_Km     Items_Count  Customer_Rating  Discount_Applied  \
# count  1000000.000000  1000000.000000    953000.000000    1000000.000000
# mean         7.750231       10.313376         3.042072          0.400883
# std          4.186665        5.630511         1.186872          0.490078
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   Order_ID                 1000000 non-null  int64
#  1   Company                  1000000 non-null  str
#  2   City                     1000000 non-null  str
#  3   Customer_Age             1000000 non-null  int64
#  4   Order_Value              1000000 non-null  float64
#  5   Delivery_Time_Min        1000000 non-null  float64
#  6   Distance_Km              1000000 non-null  float64
#  7   Items_Count              1000000 non-null  float64
#  8   Product_Category         1000000 non-null  str
#  9   Payment_Method           1000000 non-null  str
#  10  Customer_Rating          953000 non-null   float64
#  11  Discount_Applied         1000000 non-null  int64
#  12  Delivery_Partner_Rating  1000000 non-null  float64
# dtypes: float64(6), int64(3), str(4)
# ...

# %%
df['Customer_Rating'].isna().sum()
# Out:
# np.int64(47000)
